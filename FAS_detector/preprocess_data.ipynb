# %%
import os
import cv2
import numpy as np
from face_detector import FaceDetector
from utility.video_utils import VideoUtils

# Khởi tạo face detector
face_detector = FaceDetector()

# Định nghĩa thư mục đầu vào và đầu ra
input_dir = r"E:\archive_2\LCC_FASD\LCC_FASD_development\real"
output_dir = r"E:\data\valid\real"

# Đảm bảo rằng thư mục đầu ra tồn tại
os.makedirs(output_dir, exist_ok=True)

# Lặp qua tất cả các ảnh trong thư mục đầu vào
for filename in os.listdir(input_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Điều chỉnh phần mở rộng nếu cần
        image_path = os.path.join(input_dir, filename)
        
        # Đọc và xử lý ảnh
        image = cv2.imread(image_path)
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Phát hiện khuôn mặt và áp dụng biến đổi
        boxes = face_detector(np.array(image))
        
        # Thêm câu lệnh debug để kiểm tra kết quả phát hiện khuôn mặt
        if not boxes:
            print(f"No faces detected in {filename}")
            continue
        
        processed_image = VideoUtils.get_image(image, boxes)
        
        # Kiểm tra xem processed_image có hợp lệ không
        if processed_image is None or processed_image.size == 0:
            print(f"Processed image is empty for {filename}")
            continue
        
        # Chuyển đổi ảnh trở lại định dạng BGR để lưu bằng OpenCV
        #processed_image = cv2.cvtColor(processed_image, cv2.COLOR_RGB2BGR)
        
        # Lưu ảnh đã xử lý vào thư mục đầu ra với cùng tên tệp
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, processed_image)

print("Processing complete.")
# Out:
# Processing complete.

# %%
import os
import cv2
import numpy as np
from face_detector import FaceDetector
from utility.video_utils import VideoUtils

# Khởi tạo face detector
face_detector = FaceDetector()

# Định nghĩa thư mục đầu vào và đầu ra
input_dir = r"E:\archive_2\LCC_FASD\LCC_FASD_development\spoof"
output_dir = r"E:\data\valid\spoof"

# Đảm bảo rằng thư mục đầu ra tồn tại
os.makedirs(output_dir, exist_ok=True)

# Lặp qua tất cả các ảnh trong thư mục đầu vào
for filename in os.listdir(input_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Điều chỉnh phần mở rộng nếu cần
        image_path = os.path.join(input_dir, filename)
        
        # Đọc và xử lý ảnh
        image = cv2.imread(image_path)
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Phát hiện khuôn mặt và áp dụng biến đổi
        boxes = face_detector(np.array(image))
        
        # Thêm câu lệnh debug để kiểm tra kết quả phát hiện khuôn mặt
        if not boxes:
            print(f"No faces detected in {filename}")
            continue
        
        processed_image = VideoUtils.get_image(image, boxes)
        
        # Kiểm tra xem processed_image có hợp lệ không
        if processed_image is None or processed_image.size == 0:
            print(f"Processed image is empty for {filename}")
            continue
        
        # Chuyển đổi ảnh trở lại định dạng BGR để lưu bằng OpenCV
        #processed_image = cv2.cvtColor(processed_image, cv2.COLOR_RGB2BGR)
        
        # Lưu ảnh đã xử lý vào thư mục đầu ra với cùng tên tệp
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, processed_image)

print("Processing complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 23
#      20 image_path = os.path.join(input_dir, filename)
#      22 # Đọc và xử lý ảnh
# ---> 23 image = cv2.imread(image_path)
#      24 #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      25
#      26 # Phát hiện khuôn mặt và áp dụng biến đổi
#      27 boxes = face_detector(np.array(image))
#
# KeyboardInterrupt:

# %%
import os
import cv2
import numpy as np

def add_padding_and_resize(image_path, target_size=(224, 224), padding_color=(0, 255, 0)):
    image = cv2.imread(image_path)
    
    if image is None:
        raise ValueError(f"Image not found at path: {image_path}")

    # Get original image dimensions
    h, w, _ = image.shape
    max_dim = max(h, w)

    # Create a new image with padding color
    padded_image = np.full((max_dim, max_dim, 3), padding_color, dtype=np.uint8)

    # Calculate starting points
    start_x = (max_dim - w) // 2
    start_y = (max_dim - h) // 2

    # Place the original image in the center
    padded_image[start_y:start_y + h, start_x:start_x + w] = image

    # Resize to target size
    image_resized = cv2.resize(padded_image, target_size)

    return image_resized

# Define input and output directories
input_dir = r"E:\data\real"
output_dir = r"E:\final_data\real"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Adjust extensions as needed
        image_path = os.path.join(input_dir, filename)
        processed_image = add_padding_and_resize(image_path)
        
        # Save the processed image to the output directory with the same filename
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, processed_image)

print("Processing complete.")
# Out:
# Processing complete.
