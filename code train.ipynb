# %%
# !git clone https://github.com/dtruong46me/face-anti-spoofing.git

# %%
# !bash /kaggle/working/face-anti-spoofing/train_all.sh
